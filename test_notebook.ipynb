# %%
# !python.exe -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\programdata\miniconda3\lib\site-packages (26.0.1)
# Collecting pip
#   Downloading pip-26.1.2-py3-none-any.whl.metadata (4.6 kB)
# Downloading pip-26.1.2-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 11.0 MB/s  0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 26.0.1
#     Uninstalling pip-26.0.1:
#       Successfully uninstalled pip-26.0.1
# Successfully installed pip-26.1.2

# %%
# !pip install -U gurobipy
# Out:
# Collecting gurobipy
#   Downloading gurobipy-13.0.2-cp310-cp310-win_amd64.whl.metadata (17 kB)
# Downloading gurobipy-13.0.2-cp310-cp310-win_amd64.whl (11.4 MB)
#    ---------------------------------------- 0.0/11.4 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.4 MB 10.1 MB/s eta 0:00:02
#    -------- ------------------------------- 2.4/11.4 MB 7.1 MB/s eta 0:00:02
#    -------------- ------------------------- 4.2/11.4 MB 8.7 MB/s eta 0:00:01
#    ------------------- -------------------- 5.5/11.4 MB 7.3 MB/s eta 0:00:01
#    ------------------------- -------------- 7.3/11.4 MB 8.0 MB/s eta 0:00:01
#    -------------------------------- ------- 9.2/11.4 MB 7.7 MB/s eta 0:00:01
#    --------------------------------- ------ 9.4/11.4 MB 7.8 MB/s eta 0:00:01
#    --------------------------------- ------ 9.4/11.4 MB 7.8 MB/s eta 0:00:01
#    -------------------------------------- - 11.0/11.4 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.4/11.4 MB 6.0 MB/s  0:00:01
# Installing collected packages: gurobipy
# Successfully installed gurobipy-13.0.2
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gurobipy as gp
print(f"Gurobi version: {gp.gurobi.version()}")
# Out:
# Gurobi version: (13, 0, 2)
